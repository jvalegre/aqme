# %% [markdown]
# # Example 3

# %% [markdown]
# ### xTB descriptors to predict solubility using GNN

# %% [markdown]
# This workflow includes:
#
# i) RDKit conformer sampling \
# ii) xTB porperty calculations to determine molecular and atomic properties \
# iii) Generate a GNN model to predict solubility

# %% [markdown]
# #### Steps involved in this example

# %% [markdown]
# - Step 1: Import AQME and other python modules, and the required CSV
# - Step 2: Run CSEARCH (RDKit) on the CSV
# - Step 3: Run xTB calculations using QDESCP
# - Step 4: Create the CSV file with descriptors for the GNN model
# - Step 5: Run the gnn.py to get results
#   - Step 5a: Load the solubility CSV file and split the data into training, validation and test sets
#   - Step 6a: Set up the GNN model
#   - Step 7a: Predict solubities of external test set using the GNN model

# %% [markdown]
# ###  Step 1: Import AQME and other python modules, and the required CSV

# %%
import glob
from aqme.csearch import csearch
from aqme.qdescp import qdescp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from gnn_functions import *
from sklearn.metrics import r2_score
import sklearn.metrics as metrics
import tensorflow as tf

file = 'solubility.csv'
# Out:
# RDKit WARNING: [22:38:53] Enabling RDKit 2019.09.3 jupyter extensions
# [22:38:53] Enabling RDKit 2019.09.3 jupyter extensions
# 2022-12-09 22:38:54.432487: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/ASE_ANI/lib::/usr/local/cuda/lib64:/opt/anaconda/envs/DL_CPU/lib/python3.7/site-packages/xtb_6.3.pre1/lib64/:/usr/local/intel64_lin/
# 2022-12-09 22:38:54.432516: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ###  Step 2: Run CSEARCH (RDKit) on the CSV

# %%
csearch(program='rdkit',input=file,ewin_csearch=1)
# Out:
# True
# AQME v 1.4.0 2022/12/07 13:32:55
# Citation: AQME v 1.4.0, Alegre-Requena, J. V.; Sowndarya, S.; Perez-Soto, R.; Alturaifi, T. M.; Paton, R. S., 2022. https://github.com/jvalegre/aqme
#
#
#
# Starting CSEARCH with 1128 job(s) (SDF, XYZ, CSV, etc. files might contain multiple jobs/structures inside)
#
#
#
#    ----- mol_1 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_2 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_3 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_4 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_5 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_6 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_7 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_8 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_9 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_10 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_11 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_12 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_13 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_14 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_15 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_16 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_17 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_18 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_19 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_20 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_21 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_22 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_23 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_24 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_25 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_26 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_27 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_28 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_29 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_30 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_31 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_32 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_33 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_34 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_35 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_36 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_37 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_38 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_39 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_40 -----
#
#
# x  MMFF is not compatible with the molecule, changing to UFF
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_41 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_42 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_43 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_44 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_45 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_46 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_47 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_48 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_49 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_50 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_51 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_52 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_53 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_54 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_55 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_56 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_57 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_58 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_59 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_60 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_61 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_62 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_63 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_64 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_65 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_66 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_67 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_68 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_69 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_70 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_71 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_72 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_73 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_74 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_75 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_76 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_77 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_78 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_79 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_80 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_81 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_82 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_83 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_84 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_85 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_86 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_87 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_88 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_89 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_90 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_91 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_92 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_93 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_94 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_95 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_96 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_97 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_98 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_99 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_100 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_101 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_102 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_103 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_104 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_105 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_106 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_107 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_108 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_109 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_110 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_111 -----
#
#
# x  MMFF is not compatible with the molecule, changing to UFF
#
#
# x  MMFF is not compatible with the molecule, changing to UFF
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_112 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_113 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_114 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_115 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_116 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_117 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_118 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_119 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_120 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_121 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_122 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_123 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_124 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_125 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_126 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_127 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_128 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_129 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_130 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_131 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_132 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_133 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_134 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_135 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_136 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_137 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_138 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_139 -----
#
#
# x  MMFF is not compatible with the molecule, changing to UFF
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_140 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_141 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_142 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_143 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_144 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_145 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol
-----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1116 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1117 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1118 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1119 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1120 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1121 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1122 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1123 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1124 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1125 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1126 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1127 -----
#
#
# o  Applying filters to initial conformers
#
#
#    ----- mol_1128 -----
#
#
# o  Applying filters to initial conformers
#
#
# Time CSEARCH: 11339.37 seconds

# %% [markdown]
# ### Step 3 : Run xTB calculations using QDESCP

# %%
sdf_rdkit_files = glob.glob(f'CSEARCH/*.sdf')
qdescp(files=sdf_rdkit_files, boltz=True, program='xtb')

#or run with python script on terminal if the number of molecules are large

#python run_qdescp.py

# %% [markdown]
# ### Step 4 : Create the CSV file with descriptors for the GNN model

# %%
data =  pd.read_csv(file)
drop = ['mol_556','mol_641']
data = data[~data.code_name.isin(drop)]
data['xtbjson'] = data['code_name'].apply(lambda x: 'QDESCP/boltz/{}_rdkit_boltz.json'.format(x))
data.to_csv('solubility_xtb.csv',index=False)

# %% [markdown]
# ### The following steps can be done using a script as shown or run in the notebook itself

# %% [markdown]
# ###  Step 5: Run the gnn.py to get results
#
# ##### We had done it by using the gnn.py script for our result of R2=0.8

# %%
#python gnn.py

# %% [markdown]
# ###  Step 5a: Load the solubility CSV file and split the data into training, validation and test sets

# %%
sol = pd.read_csv('solubility_xtb.csv')
valid, test, train = np.split(sol[['smiles','xtbjson']].sample(frac=1., random_state=41), [50, 100])

# %% [markdown]
# ###  Step 5b: Set up the GNN dataset and model

# %%
train_dataset, valid_dataset, test_dataset = gnn_data(valid, test, train, sol)
inputs, outputs = next(train_dataset.as_numpy_iterator())
# Out:
# 2022-12-09 22:39:04.167388: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-12-09 22:39:04.170742: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-12-09 22:39:04.860272: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-12-09 22:39:04.861194: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (subzero.chem.colostate.edu): /proc/driver/nvidia/version does not exist
# 2022-12-09 22:39:04.865114: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-09 22:39:04.876947: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-12-09 22:39:04.994013: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-12-09 22:39:04.995316: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2400000000 Hz

# %%
model = gnn_model()
model.compile(loss='mae', optimizer=tf.keras.optimizers.Adam(1E-3))
model.fit(train_dataset, validation_data=valid_dataset, epochs=200)
# Out:
# Epoch 1/200
# /apps/conda/svss/envs/bm/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py:595: UserWarning: Input dict contained keys ['bond_xtb', 'bond_indices', 'bond_atom_indices', 'atom_indices'] which did not match any model input. They will be ignored by the model.
#   [n for n in tensors.keys() if n not in ref_input_names])
# WARNING:tensorflow:Gradients do not exist for variables ['dense_2/kernel:0', 'dense_2/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['dense_2/kernel:0', 'dense_2/bias:0'] when minimizing the loss.
# 1/1 [==============================] - 27s 27s/step - loss: 136.0465 - val_loss: 406.2010
# Epoch 2/200
# 1/1 [==============================] - 12s 12s/step - loss: 400.7531 - val_loss: 635.8461
# Epoch 3/200
# 1/1 [==============================] - 11s 11s/step - loss: 586.8674 - val_loss: 2141.9399
# Epoch 4/200
# 1/1 [==============================] - 10s 10s/step - loss: 1993.0375 - val_loss: 178.5393
# Epoch 5/200
# 1/1 [==============================] - 10s 10s/step - loss: 153.3541 - val_loss: 178.3852
# Epoch 6/200
# 1/1 [==============================] - 11s 11s/step - loss: 168.1695 - val_loss: 61.1060
# Epoch 7/200
# 1/1 [==============================] - 10s 10s/step - loss: 52.9542 - val_loss: 298.7231
# Epoch 8/200
# 1/1 [==============================] - 11s 11s/step - loss: 285.7153 - val_loss: 40.3114
# Epoch 9/200
# 1/1 [==============================] - 10s 10s/step - loss: 33.8565 - val_loss: 139.6445
# Epoch 10/200
# 1/1 [==============================] - 11s 11s/step - loss: 129.7855 - val_loss: 33.0402
# Epoch 11/200
# 1/1 [==============================] - 10s 10s/step - loss: 34.2889 - val_loss: 159.2378
# Epoch 12/200
# 1/1 [==============================] - 10s 10s/step - loss: 146.7440 - val_loss: 125.0794
# Epoch 13/200
# 1/1 [==============================] - 10s 10s/step - loss: 107.9444 - val_loss: 17.7439
# Epoch 14/200
# 1/1 [==============================] - 10s 10s/step - loss: 9.5247 - val_loss: 59.9668
# Epoch 15/200
# 1/1 [==============================] - 11s 11s/step - loss: 57.2916 - val_loss: 41.6729
# Epoch 16/200
# 1/1 [==============================] - 11s 11s/step - loss: 35.8499 - val_loss: 28.6055
# Epoch 17/200
# 1/1 [==============================] - 11s 11s/step - loss: 24.0791 - val_loss: 13.6957
# Epoch 18/200
# 1/1 [==============================] - 10s 10s/step - loss: 7.2265 - val_loss: 12.6528
# Epoch 19/200
# 1/1 [==============================] - 11s 11s/step - loss: 10.6696 - val_loss: 15.4089
# Epoch 20/200
# 1/1 [==============================] - 11s 11s/step - loss: 14.9120 - val_loss: 11.6783
# Epoch 21/200
# 1/1 [==============================] - 10s 10s/step - loss: 11.0915 - val_loss: 6.4373
# Epoch 22/200
# 1/1 [==============================] - 11s 11s/step - loss: 5.7548 - val_loss: 7.7269
# Epoch 23/200
# 1/1 [==============================] - 11s 11s/step - loss: 7.1857 - val_loss: 9.3525
# Epoch 24/200
# 1/1 [==============================] - 11s 11s/step - loss: 8.4261 - val_loss: 2.9703
# Epoch 25/200
# 1/1 [==============================] - 11s 11s/step - loss: 2.6955 - val_loss: 7.8595
# Epoch 26/200
# 1/1 [==============================] - 11s 11s/step - loss: 7.1592 - val_loss: 8.4034
# Epoch 27/200
# 1/1 [==============================] - 11s 11s/step - loss: 7.3679 - val_loss: 3.6618
# Epoch 28/200
# 1/1 [==============================] - 11s 11s/step - loss: 2.4083 - val_loss: 6.2224
# Epoch 29/200
# 1/1 [==============================] - 11s 11s/step - loss: 6.0406 - val_loss: 6.5911
# Epoch 30/200
# 1/1 [==============================] - 11s 11s/step - loss: 6.4735 - val_loss: 3.3336
# Epoch 31/200
# 1/1 [==============================] - 12s 12s/step - loss: 2.2583 - val_loss: 5.9881
# Epoch 32/200
# 1/1 [==============================] - 11s 11s/step - loss: 4.9820 - val_loss: 6.3834
# Epoch 33/200
# 1/1 [==============================] - 10s 10s/step - loss: 5.5801 - val_loss: 3.3034
# Epoch 34/200
# 1/1 [==============================] - 11s 11s/step - loss: 2.3330 - val_loss: 4.0432
# Epoch 35/200
# 1/1 [==============================] - 11s 11s/step - loss: 3.7526 - val_loss: 5.2253
# Epoch 36/200
# 1/1 [==============================] - 11s 11s/step - loss: 4.5740 - val_loss: 3.3089
# Epoch 37/200
# 1/1 [==============================] - 10s 10s/step - loss: 2.1725 - val_loss: 4.7966
# Epoch 38/200
# 1/1 [==============================] - 11s 11s/step - loss: 4.0747 - val_loss: 3.0666
# Epoch 39/200
# 1/1 [==============================] - 11s 11s/step - loss: 2.8969 - val_loss: 2.1574
# Epoch 40/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.8761 - val_loss: 2.3498
# Epoch 41/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.9702 - val_loss: 1.7764
# Epoch 42/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.5490 - val_loss: 2.0085
# Epoch 43/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.8008 - val_loss: 1.8312
# Epoch 44/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.7533 - val_loss: 2.0312
# Epoch 45/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.5675 - val_loss: 2.4544
# Epoch 46/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.7911 - val_loss: 2.0624
# Epoch 47/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.5806 - val_loss: 1.7331
# Epoch 48/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.5896 - val_loss: 1.7123
# Epoch 49/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.6448 - val_loss: 1.5982
# Epoch 50/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.4566 - val_loss: 1.9059
# Epoch 51/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.5544 - val_loss: 1.7558
# Epoch 52/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.4517 - val_loss: 1.5042
# Epoch 53/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.4359 - val_loss: 1.5476
# Epoch 54/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.4809 - val_loss: 1.6492
# Epoch 55/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.3434 - val_loss: 1.8652
# Epoch 56/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.4503 - val_loss: 1.4789
# Epoch 57/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.3145 - val_loss: 1.5199
# Epoch 58/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.4118 - val_loss: 1.4315
# Epoch 59/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.2774 - val_loss: 1.6541
# Epoch 60/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.3695 - val_loss: 1.3838
# Epoch 61/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.2450 - val_loss: 1.3918
# Epoch 62/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.3176 - val_loss: 1.4665
# Epoch 63/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.2106 - val_loss: 1.6740
# Epoch 64/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.2724 - val_loss: 1.4136
# Epoch 65/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.1839 - val_loss: 1.3195
# Epoch 66/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.2269 - val_loss: 1.4304
# Epoch 67/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1745 - val_loss: 1.3185
# Epoch 68/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1370 - val_loss: 1.3770
# Epoch 69/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1786 - val_loss: 1.3019
# Epoch 70/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.1079 - val_loss: 1.3981
# Epoch 71/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1286 - val_loss: 1.3413
# Epoch 72/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1600 - val_loss: 1.4092
# Epoch 73/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0882 - val_loss: 1.3147
# Epoch 74/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0486 - val_loss: 1.3653
# Epoch 75/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1056 - val_loss: 1.4029
# Epoch 76/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1180 - val_loss: 1.3260
# Epoch 77/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0472 - val_loss: 1.2776
# Epoch 78/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.0064 - val_loss: 1.2957
# Epoch 79/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0080 - val_loss: 1.2919
# Epoch 80/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.0352 - val_loss: 1.3358
# Epoch 81/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0760 - val_loss: 1.4721
# Epoch 82/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.1281 - val_loss: 1.3734
# Epoch 83/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0544 - val_loss: 1.3212
# Epoch 84/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9980 - val_loss: 1.2115
# Epoch 85/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9642 - val_loss: 1.1867
# Epoch 86/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9509 - val_loss: 1.1844
# Epoch 87/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9366 - val_loss: 1.2294
# Epoch 88/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9316 - val_loss: 1.2515
# Epoch 89/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9520 - val_loss: 1.3048
# Epoch 90/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0711 - val_loss: 1.6005
# Epoch 91/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.3463 - val_loss: 1.3128
# Epoch 92/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0960 - val_loss: 1.1883
# Epoch 93/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9509 - val_loss: 1.1184
# Epoch 94/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8996 - val_loss: 1.1400
# Epoch 95/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8884 - val_loss: 1.1075
# Epoch 96/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8855 - val_loss: 1.1357
# Epoch 97/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9196 - val_loss: 1.2149
# Epoch 98/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.0556 - val_loss: 1.4410
# Epoch 99/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1494 - val_loss: 1.2868
# Epoch 100/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.0983 - val_loss: 1.1697
# Epoch 101/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9695 - val_loss: 1.1541
# Epoch 102/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9511 - val_loss: 1.1320
# Epoch 103/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9663 - val_loss: 1.3866
# Epoch 104/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.1226 - val_loss: 1.2215
# Epoch 105/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0335 - val_loss: 1.3116
# Epoch 106/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.0262 - val_loss: 1.0702
# Epoch 107/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8895 - val_loss: 1.0538
# Epoch 108/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8431 - val_loss: 1.0243
# Epoch 109/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8451 - val_loss: 1.0362
# Epoch 110/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8580 - val_loss: 1.1333
# Epoch 111/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9902 - val_loss: 1.5658
# Epoch 112/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.3058 - val_loss: 1.0758
# Epoch 113/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9428 - val_loss: 1.0108
# Epoch 114/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8292 - val_loss: 0.9667
# Epoch 115/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8071 - val_loss: 0.9827
# Epoch 116/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8190 - val_loss: 1.0937
# Epoch 117/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8977 - val_loss: 1.4143
# Epoch 118/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.1752 - val_loss: 1.4591
# Epoch 119/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.2134 - val_loss: 0.9913
# Epoch 120/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8380 - val_loss: 1.0470
# Epoch 121/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8835 - val_loss: 1.6754
# Epoch 122/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.3690 - val_loss: 1.2278
# Epoch 123/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9510 - val_loss: 1.0449
# Epoch 124/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8255 - val_loss: 1.3186
# Epoch 125/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.1241 - val_loss: 1.4394
# Epoch 126/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.1106 - val_loss: 1.2389
# Epoch 127/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9151 - val_loss: 1.1915
# Epoch 128/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9016 - val_loss: 1.3030
# Epoch 129/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0146 - val_loss: 1.2667
# Epoch 130/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1100 - val_loss: 1.1263
# Epoch 131/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9010 - val_loss: 1.0955
# Epoch 132/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9116 - val_loss: 1.3831
# Epoch 133/200
# 1/1 [==============================] - 8s 8s/step - loss: 1.1405 - val_loss: 1.2213
# Epoch 134/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9675 - val_loss: 1.2534
# Epoch 135/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9022 - val_loss: 1.1719
# Epoch 136/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9501 - val_loss: 1.1890
# Epoch 137/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9291 - val_loss: 1.0646
# Epoch 138/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9043 - val_loss: 1.0545
# Epoch 139/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8423 - val_loss: 0.9895
# Epoch 140/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8140 - val_loss: 1.0879
# Epoch 141/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8793 - val_loss: 1.2160
# Epoch 142/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0035 - val_loss: 1.1859
# Epoch 143/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9758 - val_loss: 1.0916
# Epoch 144/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8354 - val_loss: 0.8769
# Epoch 145/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7568 - val_loss: 1.0169
# Epoch 146/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8172 - val_loss: 1.1170
# Epoch 147/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9464 - val_loss: 1.3045
# Epoch 148/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0445 - val_loss: 1.0761
# Epoch 149/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9165 - val_loss: 1.0047
# Epoch 150/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8877 - val_loss: 1.0245
# Epoch 151/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8396 - val_loss: 1.1158
# Epoch 152/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8587 - val_loss: 1.1460
# Epoch 153/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9808 - val_loss: 1.4674
# Epoch 154/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1483 - val_loss: 0.9875
# Epoch 155/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8642 - val_loss: 0.9583
# Epoch 156/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.7826 - val_loss: 0.9266
# Epoch 157/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7430 - val_loss: 0.9568
# Epoch 158/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7420 - val_loss: 0.8934
# Epoch 159/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7235 - val_loss: 0.9258
# Epoch 160/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7176 - val_loss: 0.9460
# Epoch 161/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7209 - val_loss: 0.9018
# Epoch 162/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7113 - val_loss: 0.8775
# Epoch 163/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7077 - val_loss: 0.9090
# Epoch 164/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7011 - val_loss: 0.9564
# Epoch 165/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7476 - val_loss: 1.2636
# Epoch 166/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1076 - val_loss: 1.6359
# Epoch 167/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.3491 - val_loss: 1.0098
# Epoch 168/200
# 1/1 [==============================] - 9s 9s/step - loss: 0.7889 - val_loss: 0.9103
# Epoch 169/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.6986 - val_loss: 1.0358
# Epoch 170/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8913 - val_loss: 1.7662
# Epoch 171/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.3123 - val_loss: 1.1105
# Epoch 172/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8966 - val_loss: 1.0056
# Epoch 173/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7093 - val_loss: 1.1357
# Epoch 174/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9108 - val_loss: 1.7063
# Epoch 175/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.3909 - val_loss: 1.0858
# Epoch 176/200
# 1/1 [==============================] - 12s 12s/step - loss: 0.7795 - val_loss: 1.1210
# Epoch 177/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.9055 - val_loss: 1.6349
# Epoch 178/200
# 1/1 [==============================] - 8s 8s/step - loss: 1.3805 - val_loss: 0.9801
# Epoch 179/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7759 - val_loss: 1.1244
# Epoch 180/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8645 - val_loss: 1.4790
# Epoch 181/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.3188 - val_loss: 0.9694
# Epoch 182/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7737 - val_loss: 1.0355
# Epoch 183/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.8826 - val_loss: 1.5804
# Epoch 184/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.3100 - val_loss: 0.9524
# Epoch 185/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7139 - val_loss: 1.2901
# Epoch 186/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.1375 - val_loss: 1.3538
# Epoch 187/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.1350 - val_loss: 0.8300
# Epoch 188/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.7172 - val_loss: 1.6257
# Epoch 189/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.3644 - val_loss: 0.9088
# Epoch 190/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7352 - val_loss: 1.0560
# Epoch 191/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.8552 - val_loss: 1.4433
# Epoch 192/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.2001 - val_loss: 0.9123
# Epoch 193/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7060 - val_loss: 1.2688
# Epoch 194/200
# 1/1 [==============================] - 10s 10s/step - loss: 1.0384 - val_loss: 1.0806
# Epoch 195/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.9925 - val_loss: 0.9364
# Epoch 196/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7029 - val_loss: 1.0823
# Epoch 197/200
# 1/1 [==============================] - ETA: 0s - loss: 0.802 - 10s 10s/step - loss: 0.8020 - val_loss: 1.1190
# Epoch 198/200
# 1/1 [==============================] - 11s 11s/step - loss: 1.0011 - val_loss: 0.9917
# Epoch 199/200
# 1/1 [==============================] - 10s 10s/step - loss: 0.7976 - val_loss: 0.9048
# Epoch 200/200
# 1/1 [==============================] - 11s 11s/step - loss: 0.6896 - val_loss: 0.8382

# %% [markdown]
# ### Step 5c: Predict solubities of external test set using the GNN model

# %%
# Predict solubility of the external test set
test_predictions = model.predict(test_dataset)
test_db_values = sol.set_index('smiles').reindex(test.smiles)['measured log solubility in mols per litre'].values

# Plot the results
fig = plt.subplots(figsize=(4,4))

ax1 = sns.scatterplot(x=test_db_values,y=test_predictions.flatten(),s=30,marker='o',color='b',alpha=0.5)
ax1.set_xlabel(r'Measured',fontsize=10)
ax1.set_ylabel(r'Predicted',fontsize=10)

mae = metrics.mean_absolute_error(test_db_values,test_predictions.flatten())
r2 = metrics.r2_score(test_db_values,test_predictions.flatten())

plt.annotate(f"$R^2$ = {round(r2,1)} \nMAE = {round(mae,1)} ", xy=(-2.3, -5.9), fontsize=10)
plt.savefig('solubility-gnn.jpg',dpi=400)
plt.show()
