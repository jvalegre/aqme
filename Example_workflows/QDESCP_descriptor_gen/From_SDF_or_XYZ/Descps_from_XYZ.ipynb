# %% [markdown]
# #### Organic molecules from XYZ inputs, QDESCP optimizes with xTB and produces properties with xTB and MORFEUS

# %%
import glob
from aqme.qdescp import qdescp

# set XYZ filenames
xyz_files = glob.glob(f'XYZ/*.xyz')

# run QDESCP descriptor generator, with:
# 1) Files to run (files=xyz_files)
qdescp(files=xyz_files)
